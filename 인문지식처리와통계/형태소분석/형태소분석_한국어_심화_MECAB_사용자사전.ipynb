# %% [markdown]
# <a href="https://colab.research.google.com/github/Esantomi/digital-humanities/blob/main/%EC%9D%B8%EB%AC%B8%EC%A7%80%EC%8B%9D%EC%B2%98%EB%A6%AC%EC%99%80%ED%86%B5%EA%B3%84/%ED%98%95%ED%83%9C%EC%86%8C%EB%B6%84%EC%84%9D/%ED%98%95%ED%83%9C%EC%86%8C%EB%B6%84%EC%84%9D_%ED%95%9C%EA%B5%AD%EC%96%B4_%EC%8B%AC%ED%99%94_MECAB_%EC%82%AC%EC%9A%A9%EC%9E%90%EC%82%AC%EC%A0%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 환경준비(사용자 사전)
#
# https://github.com/SOMJANG/Mecab-ko-for-Google-Colab
#
# 한국어 품사 태그 비교표:
# https://docs.google.com/spreadsheets/d/1OGAjUvalBuX-oZvZ_-9tEfYD2gQe7hTGsgUpiiBSXI8/edit#gid=0

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# !bash /content/Mecab-ko-for-Google-Colab/install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 91 (delta 43), reused 22 (delta 6), pack-reused 0
# Unpacking objects: 100% (91/91), done.
# Installing konlpy.....
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 1.2MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/cd/a5/9781e2ef4ca92d09912c4794642c1653aea7607f473e156cf4d423a881a1/JPype1-1.2.1-cp37-cp37m-manylinux2010_x86_64.whl (457kB)
#      |████████████████████████████████| 460kB 44.8MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 11.2MB/s
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: colorama, JPype1, beautifulsoup4, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.2.1 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2021-06-08 00:37:16--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::6b17:d1f5, 2406:da00:ff00::22c2:513, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=lXyJ52aLKKEz%2FhHMDQn%2BzU9W%2BsU%3D&Expires=1623113540&AWSAccessKeyId=AKIA6KOSE3BNJRRFUUX6&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None [following]
# --2021-06-08 00:37:16--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=lXyJ52aLKKEz%2FhHMDQn%2BzU9W%2BsU%3D&Expires=1623113540&AWSAccessKeyId=AKIA6KOSE3BNJRRFUUX6&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.88.123
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.88.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  3.21MB/s    in 0.4s
#
# 2021-06-08 00:37:17 (3.21 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2021-06-08 00:38:33--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22c2:513, 2406:da00:ff00::6b17:d1f5, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=PKCaIEdBbXsjzODyPGnlh2SGKL0%3D&Expires=1623114271&AWSAccessKeyId=AKIA6KOSE3BNJRRFUUX6&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None [following]
# --2021-06-08 00:38:33--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=PKCaIEdBbXsjzODyPGnlh2SGKL0%3D&Expires=1623114271&AWSAccessKeyId=AKIA6KOSE3BNJRRFUUX6&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.217.36.124
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.217.36.124|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  24.8MB/s    in 1.9s
#
# 2021-06-08 00:38:35 (24.8 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# apt-get update
# apt-get upgrade
# apt install curl
# apt install git
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Done
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.

# %%
from konlpy.tag import Mecab
mecab = Mecab()

mecab.pos("나레카는 오늘도 행복합니다.")
# Out:
# [('나', 'NP'),
#  ('레카', 'NNP'),
#  ('는', 'JX'),
#  ('오늘', 'NNG'),
#  ('도', 'JX'),
#  ('행복', 'NNG'),
#  ('합니다', 'XSA+EF'),
#  ('.', 'SF')]

# %%
import pandas as pd

nnp_df = pd.read_csv("/content/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv")
nnp_df
# Out:
#    대우  Unnamed: 1  Unnamed: 2  Unnamed: 3  NNP  *  F 대우.1 *.1 *.2 *.3 *.4 *.5
# 0  구글         NaN         NaN         NaN  NNP  *  T   구글   *   *   *   *   *

# %%
# !pip install jamo
from jamo import h2j, j2hcj


def get_jongsung_TF(sample_text):
    sample_text_list = list(sample_text)
    last_word = sample_text_list[-1]
    last_word_jamo_list = list(j2hcj(h2j(last_word)))
    last_jamo = last_word_jamo_list[-1]

    jongsung_TF = "T"

    if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
        jongsung_TF = "F"

    return jongsung_TF
# Out:
# Collecting jamo
#   Downloading https://files.pythonhosted.org/packages/ac/cc/49812faae67f9a24be6ddaf58a2cf7e8c3cbfcf5b762d9414f7103d2ea2c/jamo-0.4.1-py3-none-any.whl
# Installing collected packages: jamo
# Successfully installed jamo-0.4.1

# %%
with open("/content/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv", 'r', encoding='utf-8') as f:
  file_data = f.readlines()

word_list = ['나레카', '에디', '자가', '아미르', '석훈']

for word in word_list:
  jongsung_TF = get_jongsung_TF(word)

  line = '{},,,,NNP,*,{},{},*,*,*,*,*\n'.format(word, jongsung_TF, word)

  file_data.append(line)
  
with open("/content/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv", 'w', encoding='utf-8') as f:
  for line in file_data:
    f.write(line)

# %%
import pandas as pd

nnp_df = pd.read_csv("/content/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv")
nnp_df
# Out:
#      대우  Unnamed: 1  Unnamed: 2  Unnamed: 3  NNP  *  F 대우.1 *.1 *.2 *.3 *.4 *.5
# 0    구글         NaN         NaN         NaN  NNP  *  T   구글   *   *   *   *   *
# 1   나레카         NaN         NaN         NaN  NNP  *  F  나레카   *   *   *   *   *
# 2    에디         NaN         NaN         NaN  NNP  *  F   에디   *   *   *   *   *
# 3    자가         NaN         NaN         NaN  NNP  *  F   자가   *   *   *   *   *
# 4   아미르         NaN         NaN         NaN  NNP  *  F  아미르   *   *   *   *   *
# ..  ...         ...         ...         ...  ... .. ..  ...  ..  ..  ..  ..  ..
# 70   나미         NaN         NaN         NaN  NNP  *  F   나미   *   *   *   *   *
# 71   미영         NaN         NaN         NaN  NNP  *  T   미영   *   *   *   *   *
# 72  김영철         NaN         NaN         NaN  NNP  *  T  김영철   *   *   *   *   *
# 73  김정민         NaN         NaN         NaN  NNP  *  T  김정민   *   *   *   *   *
# 74    샘         NaN         NaN         NaN  NNP  *  T    샘   *   *   *   *   *
#
# [75 rows x 13 columns]

# %%
# !bash /content/mecab-ko-dic-2.1.1-20180720/tools/add-userdic.sh
# Out:
# generating userdic...
# nnp.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/nnp.csv ...
# done!
# person.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/person.csv ...
# done!
# place.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/place.csv ...
# done!
# test -z "model.bin matrix.bin char.bin sys.dic unk.dic" || rm -f model.bin matrix.bin char.bin sys.dic unk.dic
# /usr/local/libexec/mecab/mecab-dict-index -d . -o . -f UTF-8 -t UTF-8
# reading ./unk.def ... 13
# emitting double-array: 100% |###########################################|
# reading ./VX.csv ... 125
# reading ./VV.csv ... 7331
# reading ./XSA.csv ... 19
# reading ./NorthKorea.csv ... 3
# reading ./Hanja.csv ... 125750
# reading ./Place-station.csv ... 1145
# reading ./EP.csv ... 51
# reading ./VCN.csv ... 7
# reading ./CoinedWord.csv ... 148
# reading ./NR.csv ... 482
# reading ./Symbol.csv ... 16
# reading ./XSN.csv ... 124
# reading ./XR.csv ... 3637
# reading ./XSV.csv ... 23
# reading ./EC.csv ... 2547
# reading ./MM.csv ... 453
# reading ./Person-actor.csv ... 99230
# reading ./Foreign.csv ... 11690
# reading ./NNBC.csv ... 677
# reading ./NP.csv ... 342
# reading ./Group.csv ... 3176
# reading ./EF.csv ... 1820
# reading ./VA.csv ... 2360
# reading ./ETM.csv ... 133
# reading ./IC.csv ... 1305
# reading ./J.csv ... 416
# reading ./MAJ.csv ... 240
# reading ./user-nnp.csv ... 76
# reading ./XPN.csv ... 83
# reading ./NNG.csv ... 208524
# reading ./user-place.csv ... 2
# reading ./user-person.csv ... 1
# reading ./NNB.csv ... 140
# reading ./Preanalysis.csv ... 5
# reading ./ETN.csv ... 14
# reading ./NNP.csv ... 2371
# reading ./VCP.csv ... 9
# reading ./Wikipedia.csv ... 36762
# reading ./Person.csv ... 196459
# reading ./Inflect.csv ... 44820
# reading ./MAG.csv ... 14242
# reading ./Place-address.csv ... 19301
# reading ./Place.csv ... 30303
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 3822x2693
# emitting matrix      : 100% |###########################################|
#
# done!
# echo To enable dictionary, rewrite /usr/local/etc/mecabrc as \"dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic\"
# To enable dictionary, rewrite /usr/local/etc/mecabrc as "dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic"

# %%
cd mecab-ko-dic-2.1.1-20180720
# Out:
# /content/mecab-ko-dic-2.1.1-20180720

# %%
# !make install
# Out:
# make[1]: Entering directory '/content/mecab-ko-dic-2.1.1-20180720'
# make[1]: Nothing to be done for 'install-exec-am'.
#  /bin/mkdir -p '/usr/local/lib/mecab/dic/mecab-ko-dic'
#  /usr/bin/install -c -m 644 model.bin matrix.bin char.bin sys.dic unk.dic left-id.def right-id.def rewrite.def pos-id.def dicrc '/usr/local/lib/mecab/dic/mecab-ko-dic'
# make[1]: Leaving directory '/content/mecab-ko-dic-2.1.1-20180720'

# %%
from konlpy.tag import Mecab
mecab = Mecab()

mecab.pos("나레카는 오늘도 행복합니다.")
# Out:
# [('나레카', 'NNP'),
#  ('는', 'JX'),
#  ('오늘', 'NNG'),
#  ('도', 'JX'),
#  ('행복', 'NNG'),
#  ('합니다', 'XSA+EF'),
#  ('.', 'SF')]

# %% [markdown]
# # 데이터 불러오기

# %%
# 구글 드라이브 연결을 위한 기본 세팅
# !pip install -U -q PyDrive
 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
 
# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
## 문서 ID로 실제 파일 불러오기
# 실습을 위한 역대 대통령 취임사: 노무현, 이명박, 박근혜, 문재인
## https://drive.google.com/open?id=1VEdcJErjAjj2ul5gnS0-IgKrpGy0NEAK

rawdata_downloaded = drive.CreateFile({'id': '1VEdcJErjAjj2ul5gnS0-IgKrpGy0NEAK'})
rawdata_downloaded.GetContentFile('rawdata.tsv')

# %%
import numpy as np
import pandas as pd
import codecs

# %%
# "rawdata.txt" 파일의 내용을 "원본데이터" 변수로 불러오기
원본데이터 = pd.read_csv('rawdata.tsv', sep="\t")

# %%
# "원본데이터" 변수 내용 확인하기
원본데이터
# Out:
#    id type                                               text
# 0   1  노무현  존경하는 국민 여러분.   오늘 저는 대한민국의 제16대 대통령에 취임하기 위해 이...
# 1   2  이명박  존경하는 국민 여러분!  700만 해외동포 여러분, 이 자리에 참석하신 노무현, 김...
# 2   3  박근혜  희망의 새 시대를 열겠습니다.  존경하는 국민 여러분! 700만 해외동포 여러분! ...
# 3   4  문재인  존경하고 사랑하는 국민 여러분, 감사합니다. 국민 여러분의 위대한 선택에 머리 숙여...

# %% [markdown]
# # 분석 프로세스

# %%
# "원본데이터"를 대상으로 "mecab"를 사용해서 형태소 분석하기
from itertools import product
import numpy as np
import mecab
mecab = mecab.MeCab()

저장공간  = []
for index, row in 원본데이터.iterrows():# 원본데이터의 컬럼(열)을 불러와서 반복할 준비!
    대상텍스트 = row[2] # 분석에서 사용할 텍스트 정보가 있는 열을 지정해준다. 주의! python은 0부터 시작한다!
    분류 = row[1] # 분석에서 사용할 분류 정보가 있는 열을 지정해준다. 주의! python은 0부터 시작한다!
    형태소 = list(mecab.pos(대상텍스트))  # mecab의 pos 기능을 활용해서 대상 텍스트를 형태소 분리한다.
    형태소종합 = pd.DataFrame.from_records(형태소) # 형태소에 저장된 내용을 데이터프레임 형태로 해서 형태소종합으로 저장한다.
    형태소종합['type'] = 분류 # 형태소종합에 분류정보를 추가한다.
    형태소종합['count'] = 1   # 형태소종합에 카운트정보를 추가한다.   
    저장공간.append(형태소종합) # 형태소종합의 내용을 종합하여 저장한다.

# %%
# "형태소" 변수의 저장 내용 확인
형태소
# Out:
# [('존경', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('사랑', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('국민', 'NNG'),
#  ('여러분', 'NP'),
#  (',', 'SC'),
#  ('감사', 'NNG'),
#  ('합니다', 'XSV+EF'),
#  ('.', 'SF'),
#  ('국민', 'NNG'),
#  ('여러분', 'NP'),
#  ('의', 'JKG'),
#  ('위대', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('선택', 'NNG'),
#  ('에', 'JKB'),
#  ('머리', 'NNG'),
#  ('숙여', 'VV+EC'),
#  ('깊이', 'MAG'),
#  ('감사', 'NNG'),
#  ('드립니다', 'VV+EF'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('는', 'JX'),
#  ('오늘', 'MAG'),
#  ('대한민국', 'NNP'),
#  ('제', 'XPN'),
#  ('19', 'SN'),
#  ('대', 'NNBC'),
#  ('대통령', 'NNG'),
#  ('으로서', 'JKB'),
#  ('새로운', 'VA+ETM'),
#  ('대한민국', 'NNP'),
#  ('을', 'JKO'),
#  ('향해', 'VV+EC'),
#  ('첫', 'MM'),
#  ('걸음', 'NNG'),
#  ('을', 'JKO'),
#  ('내딛', 'VV'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('지금', 'MAG'),
#  ('제', 'MM'),
#  ('두', 'MM'),
#  ('어깨', 'NNG'),
#  ('는', 'JX'),
#  ('국민', 'NNG'),
#  ('여러분', 'NP'),
#  ('으로부터', 'JKB'),
#  ('부여', 'NNG'),
#  ('받', 'VV'),
#  ('은', 'ETM'),
#  ('막중', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('소', 'XPN'),
#  ('명감', 'NNG'),
#  ('으로', 'JKB'),
#  ('무겁', 'VA'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('지금', 'MAG'),
#  ('제', 'MM'),
#  ('가슴', 'NNG'),
#  ('은', 'JX'),
#  ('한', 'MM'),
#  ('번', 'NNBC'),
#  ('도', 'JX'),
#  ('경험', 'NNG'),
#  ('하', 'XSV'),
#  ('지', 'EC'),
#  ('못한', 'VX+ETM'),
#  ('나라', 'NNG'),
#  ('를', 'JKO'),
#  ('만들', 'VV'),
#  ('겠', 'EP'),
#  ('다는', 'ETM'),
#  ('열정', 'NNG'),
#  ('으로', 'JKB'),
#  ('뜨겁', 'VA'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('그리고', 'MAJ'),
#  ('지금', 'MAG'),
#  ('제', 'MM'),
#  ('머리', 'NNG'),
#  ('는', 'JX'),
#  ('통합', 'NNG'),
#  ('과', 'JC'),
#  ('공존', 'NNG'),
#  ('의', 'JKG'),
#  ('새로운', 'VA+ETM'),
#  ('세상', 'NNG'),
#  ('을', 'JKO'),
#  ('열', 'VV'),
#  ('어', 'EC'),
#  ('갈', 'VX+ETM'),
#  ('청사진', 'NNG'),
#  ('으로', 'JKB'),
#  ('가득', 'MAG'),
#  ('차', 'VV+EC'),
#  ('있', 'VX'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('우리', 'NP'),
#  ('가', 'JKS'),
#  ('만들', 'VV'),
#  ('어', 'EC'),
#  ('가', 'VX'),
#  ('려는', 'ETM'),
#  ('새로운', 'VA+ETM'),
#  ('대한민국', 'NNP'),
#  ('은', 'JX'),
#  ('숱한', 'VA+ETM'),
#  ('좌절', 'NNG'),
#  ('과', 'JC'),
#  ('패배', 'NNG'),
#  ('에', 'JKB'),
#  ('도', 'JX'),
#  ('불구', 'XR'),
#  ('하', 'XSA'),
#  ('고', 'EC'),
#  ('우리', 'NP'),
#  ('의', 'JKG'),
#  ('선대', 'NNG'),
#  ('들', 'XSN'),
#  ('이', 'JKS'),
#  ('일관', 'NNG'),
#  ('되게', 'MAG'),
#  ('추구', 'NNG'),
#  ('했', 'XSV+EP'),
#  ('던', 'ETM'),
#  ('나라', 'NNG'),
#  ('입니다', 'VCP+EF'),
#  ('.', 'SF'),
#  ('또', 'MAG'),
#  ('많', 'VA'),
#  ('은', 'ETM'),
#  ('희생', 'NNG'),
#  ('과', 'JC'),
#  ('헌신', 'NNG'),
#  ('을', 'JKO'),
#  ('감내', 'NNG'),
#  ('하', 'XSV'),
#  ('며', 'EC'),
#  ('우리', 'NP'),
#  ('젊은이', 'NNG'),
#  ('들', 'XSN'),
#  ('이', 'JKS'),
#  ('그토록', 'MAG'),
#  ('이루', 'VV'),
#  ('고', 'EC'),
#  ('싶', 'VX'),
#  ('어', 'EC'),
#  ('했', 'VX+EP'),
#  ('던', 'ETM'),
#  ('나라', 'NNG'),
#  ('입니다', 'VCP+EF'),
#  ('.', 'SF'),
#  ('그런', 'MM'),
#  ('대한민국', 'NNP'),
#  ('을', 'JKO'),
#  ('만들', 'VV'),
#  ('기', 'ETN'),
#  ('위해', 'VV+EC'),
#  ('저', 'NP'),
#  ('는', 'JX'),
#  ('역사', 'NNG'),
#  ('와', 'JC'),
#  ('국민', 'NNG'),
#  ('앞', 'NNG'),
#  ('에', 'JKB'),
#  ('두렵', 'VA'),
#  ('지만', 'EC'),
#  ('겸허', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('마음', 'NNG'),
#  ('으로', 'JKB'),
#  ('대한민국', 'NNP'),
#  ('제', 'XPN'),
#  ('19', 'SN'),
#  ('대', 'NNBC'),
#  ('대통령', 'NNG'),
#  ('으로서', 'JKB'),
#  ('의', 'JKG'),
#  ('책임', 'NNG'),
#  ('과', 'JC'),
#  ('소명', 'NNG'),
#  ('을', 'JKO'),
#  ('다', 'MAG'),
#  ('할', 'VV+ETM'),
#  ('것', 'NNB'),
#  ('임', 'VCP+ETN'),
#  ('을', 'JKO'),
#  ('천명', 'NNG'),
#  ('합니다', 'XSV+EF'),
#  ('.', 'SF'),
#  ('함께', 'MAG'),
#  ('선거', 'NNG'),
#  ('를', 'JKO'),
#  ('치른', 'VV+ETM'),
#  ('후보', 'NNG'),
#  ('들', 'XSN'),
#  ('께', 'JKB'),
#  ('감사', 'NNG'),
#  ('의', 'JKG'),
#  ('말씀', 'NNG'),
#  ('과', 'JKB'),
#  ('함께', 'MAG'),
#  ('심심', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('위로', 'NNG'),
#  ('를', 'JKO'),
#  ('전합니다', 'VV+EF'),
#  ('.', 'SF'),
#  ('이번', 'NNG'),
#  ('선거', 'NNG'),
#  ('에서', 'JKB'),
#  ('는', 'JX'),
#  ('승자', 'NNG'),
#  ('도', 'JX'),
#  (',', 'SC'),
#  ('패자', 'NNG'),
#  ('도', 'JX'),
#  ('없', 'VA'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('우리', 'NP'),
#  ('는', 'JX'),
#  ('새로운', 'VA+ETM'),
#  ('대한민국', 'NNP'),
#  ('을', 'JKO'),
#  ('함께', 'MAG'),
#  ('이끌', 'VV'),
#  ('어', 'EC'),
#  ('가', 'VX'),
#  ('야', 'EC'),
#  ('할', 'VX+ETM'),
#  ('동반자', 'NNG'),
#  ('입니다', 'VCP+EF'),
#  ('.', 'SF'),
#  ('이제', 'MAG'),
#  ('치열', 'NNG'),
#  ('했', 'XSV+EP'),
#  ('던', 'ETM'),
#  ('경쟁', 'NNG'),
#  ('의', 'JKG'),
#  ('순간', 'NNG'),
#  ('을', 'JKO'),
#  ('뒤', 'NNG'),
#  ('로', 'JKB'),
#  ('하', 'VV'),
#  ('고', 'EC'),
#  ('함께', 'MAG'),
#  ('손', 'NNG'),
#  ('을', 'JKO'),
#  ('맞잡', 'VV'),
#  ('고', 'EC'),
#  ('앞', 'NNG'),
#  ('으로', 'JKB'),
#  ('전진', 'NNG'),
#  ('해야', 'XSV+EC'),
#  ('합니다', 'VX+EF'),
#  ('.', 'SF'),
#  ('존경', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('국민', 'NNG'),
#  ('여러분', 'NP'),
#  (',', 'SC'),
#  ('지난', 'VV+ETM'),
#  ('몇', 'MM'),
#  ('달', 'NNBC'),
#  ('우리', 'NP'),
#  ('는', 'JX'),
#  ('유례없', 'VA'),
#  ('는', 'ETM'),
#  ('정치', 'NNG'),
#  ('적', 'XSN'),
#  ('격변기', 'NNG'),
#  ('를', 'JKO'),
#  ('보냈', 'VV+EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('정치', 'NNG'),
#  ('는', 'JX'),
#  ('혼란', 'NNG'),
#  ('스러웠', 'XSA+EP'),
#  ('지만', 'EC'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('위대', 'XR'),
#  ('했', 'XSA+EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('현직', 'NNG'),
#  ('대통령', 'NNG'),
#  ('의', 'JKG'),
#  ('탄핵', 'NNG'),
#  ('과', 'JC'),
#  ('구속', 'NNG'),
#  ('앞', 'NNG'),
#  ('에서', 'JKB'),
#  ('도', 'JX'),
#  ('국민', 'NNG'),
#  ('들', 'XSN'),
#  ('이', 'JKS'),
#  ('대한민국', 'NNP'),
#  ('의', 'JKG'),
#  ('앞길', 'NNG'),
#  ('을', 'JKO'),
#  ('열', 'VV'),
#  ('어', 'EC'),
#  ('주', 'VX'),
#  ('셨', 'EP+EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('우리', 'NP'),
#  ('국민', 'NNG'),
#  ('들', 'XSN'),
#  ('은', 'JX'),
#  ('좌절', 'NNG'),
#  ('하', 'XSV'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('고', 'EC'),
#  ('오히려', 'MAJ'),
#  ('이', 'NP'),
#  ('를', 'JKO'),
#  ('전화위복', 'NNG'),
#  ('의', 'JKG'),
#  ('계기', 'NNG'),
#  ('로', 'JKB'),
#  ('승화', 'NNG'),
#  ('시켜', 'XSV+EC'),
#  ('마침내', 'MAG'),
#  ('오늘', 'MAG'),
#  ('새로운', 'VA+ETM'),
#  ('세상', 'NNG'),
#  ('을', 'JKO'),
#  ('열', 'VV'),
#  ('었', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('대한민국', 'NNP'),
#  ('의', 'JKG'),
#  ('위대', 'XR'),
#  ('함', 'XSA+ETN'),
#  ('은', 'JX'),
#  ('국민', 'NNG'),
#  ('의', 'JKG'),
#  ('위대', 'XR'),
#  ('함입니다', 'XSA+ETN+VCP+EF'),
#  ('.', 'SF'),
#  ('그리고', 'MAJ'),
#  ('이번', 'NNG'),
#  ('대통령', 'NNG'),
#  ('선거', 'NNG'),
#  ('에서', 'JKB'),
#  ('우리', 'NP'),
#  ('국민', 'NNG'),
#  ('들', 'XSN'),
#  ('은', 'JX'),
#  ('또', 'MAG'),
#  ('하나', 'NR'),
#  ('의', 'JKG'),
#  ('역사', 'NNG'),
#  ('를', 'JKO'),
#  ('만들', 'VV'),
#  ('어', 'EC'),
#  ('주', 'VX'),
#  ('셨', 'EP+EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('전국', 'NNG'),
#  ('각지', 'NNG'),
#  ('에서', 'JKB'),
#  ('골', 'NNG'),
#  ('고른', 'VA+ETM'),
#  ('지지', 'NNG'),
#  ('로', 'JKB'),
#  ('새로운', 'VA+ETM'),
#  ('대통령', 'NNG'),
#  ('을', 'JKO'),
#  ('선택', 'NNG'),
#  ('해', 'XSV+EC'),
#  ('주', 'VX'),
#  ('셨', 'EP+EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('오늘', 'NNG'),
#  ('부터', 'JX'),
#  ('저', 'NP'),
#  ('는', 'JX'),
#  ('국민', 'NNG'),
#  ('모두', 'NNG'),
#  ('의', 'JKG'),
#  ('대통령', 'NNG'),
#  ('이', 'JKS'),
#  ('되', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('를', 'JKO'),
#  ('지지', 'NNG'),
#  ('하', 'XSV'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('았', 'EP'),
#  ('던', 'ETM'),
#  ('국민', 'NNG'),
#  ('한', 'MM'),
#  ('분', 'NNBC'),
#  ('한', 'MM'),
#  ('분', 'NNBC'),
#  ('도', 'JX'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('국민', 'NNG'),
#  ('이', 'VCP'),
#  ('고', 'EC'),
#  ('우리', 'NP'),
#  ('의', 'JKG'),
#  ('국민', 'NNG'),
#  ('으로', 'JKB'),
#  ('섬기', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('는', 'JX'),
#  ('감히', 'MAG'),
#  ('약속', 'NNG'),
#  ('드립니다', 'VV+EF'),
#  ('.', 'SF'),
#  ('2017', 'SN'),
#  ('년', 'NNBC'),
#  ('5', 'SN'),
#  ('월', 'NNBC'),
#  ('10', 'SN'),
#  ('일', 'NNBC'),
#  (',', 'SC'),
#  ('이날', 'NNG'),
#  ('은', 'JX'),
#  ('진정한', 'VA+ETM'),
#  ('국민', 'NNG'),
#  ('통합', 'NNG'),
#  ('이', 'JKS'),
#  ('시작', 'NNG'),
#  ('된', 'XSV+ETM'),
#  ('해', 'NNG'),
#  ('로', 'JKB'),
#  ('역사', 'NNG'),
#  ('에', 'JKB'),
#  ('기록', 'NNG'),
#  ('될', 'XSV+ETM'),
#  ('것', 'NNB'),
#  ('입니다', 'VCP+EF'),
#  ('.', 'SF'),
#  ('존경', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('사랑', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('국민', 'NNG'),
#  ('여러분', 'NP'),
#  (',', 'SC'),
#  ('힘들', 'VA'),
#  ('었', 'EP'),
#  ('던', 'ETM'),
#  ('지난', 'VV+ETM'),
#  ('세월', 'NNG'),
#  ('국민', 'NNG'),
#  ('들', 'XSN'),
#  ('은', 'JX'),
#  ('이게', 'NP+JKS'),
#  ('나라', 'NNG'),
#  ('냐고', 'VCP+EC'),
#  ('물', 'VV'),
#  ('었', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('대통령', 'NNG'),
#  ('문재인', 'NNP'),
#  ('은', 'JX'),
#  ('바로', 'MAG'),
#  ('그', 'MM'),
#  ('질문', 'NNG'),
#  ('에서', 'JKB'),
#  ('새로', 'MAG'),
#  ('시작', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('오늘', 'NNG'),
#  ('부터', 'JX'),
#  ('나라', 'NNG'),
#  ('를', 'JKO'),
#  ('나라', 'NNG'),
#  ('답', 'XSA'),
#  ('게', 'EC'),
#  ('만드', 'VV'),
#  ('는', 'ETM'),
#  ('대통령', 'NNG'),
#  ('이', 'JKS'),
#  ('되', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('구시대', 'NNG'),
#  ('의', 'JKG'),
#  ('잘못', 'NNG'),
#  ('된', 'XSV+ETM'),
#  ('관행', 'NNG'),
#  ('과', 'JKB'),
#  ('과감히', 'MAG'),
#  ('결별', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('대통령', 'NNG'),
#  ('부터', 'JX'),
#  ('새로워', 'VA+EC'),
#  ('지', 'VX'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('우선', 'MAG'),
#  ('권위', 'NNG'),
#  ('적', 'XSN'),
#  ('인', 'VCP+ETM'),
#  ('대통령', 'NNG'),
#  ('문화', 'NNG'),
#  ('를', 'JKO'),
#  ('청산', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('준비', 'NNG'),
#  ('를', 'JKO'),
#  ('마치', 'VV'),
#  ('는', 'ETM'),
#  ('대로', 'NNB'),
#  ('지금', 'NNG'),
#  ('의', 'JKG'),
#  ('청와대', 'NNP'),
#  ('에서', 'JKB'),
#  ('나와', 'VV+EC'),
#  ('광화문', 'NNG'),
#  ('대통령', 'NNG'),
#  ('시대', 'NNG'),
#  ('를', 'JKO'),
#  ('열', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('참모', 'NNG'),
#  ('들', 'XSN'),
#  ('과', 'JC'),
#  ('머리', 'NNG'),
#  ('와', 'JC'),
#  ('어깨', 'NNG'),
#  ('를', 'JKO'),
#  ('맞대', 'VV'),
#  ('고', 'EC'),
#  ('토론', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('국민', 'NNG'),
#  ('과', 'JKB'),
#  ('수시로', 'MAG'),
#  ('소통', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('대통령', 'NNG'),
#  ('이', 'JKS'),
#  ('되', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('주요', 'NNG'),
#  ('사안', 'NNG'),
#  ('은', 'JX'),
#  ('대통령', 'NNG'),
#  ('이', 'JKS'),
#  ('직접', 'MAG'),
#  ('언론', 'NNG'),
#  ('에', 'JKB'),
#  ('브리핑', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('퇴근길', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('시장', 'NNG'),
#  ('에', 'JKB'),
#  ('들러', 'VV+EC'),
#  ('마주치', 'VV'),
#  ('는', 'ETM'),
#  ('시민', 'NNG'),
#  ('들', 'XSN'),
#  ('과', 'JC'),
#  ('격의', 'NNG'),
#  ('없', 'VA'),
#  ('는', 'ETM'),
#  ('대화', 'NNG'),
#  ('를', 'JKO'),
#  ('나누', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('때로', 'MAG'),
#  ('는', 'JX'),
#  ('광화문', 'NNG'),
#  ('광장', 'NNG'),
#  ('에서', 'JKB'),
#  ('대', 'XPN'),
#  ('토론회', 'NNG'),
#  ('를', 'JKO'),
#  ('열', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('대통령', 'NNG'),
#  ('의', 'JKG'),
#  ('제왕', 'NNG'),
#  ('적', 'XSN'),
#  ('권력', 'NNG'),
#  ('을', 'JKO'),
#  ('최대한', 'MAG'),
#  ('나누', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('권력', 'NNG'),
#  ('기관', 'NNG'),
#  ('은', 'JX'),
#  ('정치', 'NNG'),
#  ('로부터', 'JKB'),
#  ('완전히', 'MAG'),
#  ('독립', 'NNG'),
#  ('시키', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('그', 'IC'),
#  ('어떤', 'MM'),
#  ('기관', 'NNG'),
#  ('도', 'JX'),
#  ('무소불위', 'NNG'),
#  ('의', 'JKG'),
#  ('권력', 'NNG'),
#  ('을', 'JKO'),
#  ('행사', 'NNG'),
#  ('할', 'XSV+ETM'),
#  ('수', 'NNB'),
#  ('없', 'VA'),
#  ('도록', 'EC'),
#  ('견제', 'NNG'),
#  ('장치', 'NNG'),
#  ('를', 'JKO'),
#  ('만들', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('낮', 'VA'),
#  ('은', 'ETM'),
#  ('자세', 'NNG'),
#  ('로', 'JKB'),
#  ('일', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('국민', 'NNG'),
#  ('과', 'JC'),
#  ('눈높이', 'NNG'),
#  ('를', 'JKO'),
#  ('맞추', 'VV'),
#  ('는', 'ETM'),
#  ('대통령', 'NNG'),
#  ('이', 'JKS'),
#  ('되', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('안보', 'NNG'),
#  ('위기', 'NNG'),
#  ('도', 'JX'),
#  ('서둘러', 'VV+EC'),
#  ('해결', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('한반도', 'NNP'),
#  ('의', 'JKG'),
#  ('평화', 'NNG'),
#  ('를', 'JKO'),
#  ('위해', 'VV+EC'),
#  ('동분서주', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('필요', 'NNG'),
#  ('하', 'XSA'),
#  ('면', 'EC'),
#  ('곧바로', 'MAG'),
#  ('워싱턴', 'NNP'),
#  ('으로', 'JKB'),
#  ('날아가', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('베이징', 'NNP'),
#  ('과', 'JC'),
#  ('도쿄', 'NNP'),
#  ('에', 'JKB'),
#  ('도', 'JX'),
#  ('가', 'VV'),
#  ('고', 'EC'),
#  ('여건', 'NNG'),
#  ('이', 'JKS'),
#  ('조성', 'NNG'),
#  ('되', 'XSV'),
#  ('면', 'EC'),
#  ('평양', 'NNP'),
#  ('에', 'JKB'),
#  ('도', 'JX'),
#  ('가', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('한반도', 'NNP'),
#  ('의', 'JKG'),
#  ('평화', 'NNG'),
#  ('정착', 'NNG'),
#  ('을', 'JKO'),
#  ('위해서', 'VV+EC+VCP'),
#  ('라면', 'EC'),
#  ('제', 'NP'),
#  ('가', 'JKS'),
#  ('할', 'VV+ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('모든', 'MM'),
#  ('일', 'NNG'),
#  ('을', 'JKO'),
#  ('다', 'MAG'),
#  ('하', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('한', 'MM'),
#  ('미', 'NNG'),
#  ('동맹', 'NNG'),
#  ('은', 'JX'),
#  ('더욱', 'MAG'),
#  ('강화', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('한편', 'NNG'),
#  ('으로', 'JKB'),
#  ('사드', 'NNP'),
#  ('문제', 'NNG'),
#  ('해결', 'NNG'),
#  ('을', 'JKO'),
#  ('위해', 'VV+EC'),
#  ('미국', 'NNP'),
#  ('및', 'MAJ'),
#  ('중국', 'NNP'),
#  ('과', 'JC'),
#  ('진지', 'XR'),
#  ('하', 'XSA'),
#  ('게', 'EC'),
#  ('협상', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('튼튼', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('안', 'MAG'),
#  ('보', 'VV'),
#  ('는', 'ETM'),
#  ('막강', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('국방력', 'NNG'),
#  ('에서', 'JKB'),
#  ('비롯', 'XR'),
#  ('됩니다', 'XSV+EF'),
#  ('.', 'SF'),
#  ('자주', 'MAG'),
#  ('국방력', 'NNG'),
#  ('을', 'JKO'),
#  ('강화', 'NNG'),
#  ('하', 'XSV'),
#  ('기', 'ETN'),
#  ('위해', 'VV+EC'),
#  ('노력', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('북', 'NNP'),
#  ('핵', 'NNG'),
#  ('문제', 'NNG'),
#  ('를', 'JKO'),
#  ('해결', 'NNG'),
#  ('할', 'XSV+ETM'),
#  ('토대', 'NNG'),
#  ('도', 'JX'),
#  ('마련', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('동북아', 'NNP'),
#  ('평화', 'NNG'),
#  ('구조', 'NNG'),
#  ('를', 'JKO'),
#  ('정착', 'NNG'),
#  ('시킴', 'XSV+ETN'),
#  ('으로써', 'JKB'),
#  ('한반도', 'NNP'),
#  ('긴장', 'NNG'),
#  ('완화', 'NNG'),
#  ('의', 'JKG'),
#  ('전기', 'NNG'),
#  ('를', 'JKO'),
#  ('마련', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('분열', 'NNG'),
#  ('과', 'JC'),
#  ('갈등', 'NNG'),
#  ('의', 'JKG'),
#  ('정치', 'NNG'),
#  ('도', 'JX'),
#  ('바꾸', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('보수', 'NNG'),
#  ('와', 'JC'),
#  ('진보', 'NNG'),
#  ('의', 'JKG'),
#  ('갈등', 'NNG'),
#  ('은', 'JX'),
#  ('끝', 'NNG'),
#  ('나야', 'VV+EC'),
#  ('합니다', 'VX+EF'),
#  ('.', 'SF'),
#  ('대통령', 'NNG'),
#  ('이', 'JKS'),
#  ('나서', 'VV'),
#  ('서', 'EC'),
#  ('직접', 'MAG'),
#  ('대화', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('야당', 'NNG'),
#  ('은', 'JX'),
#  ('국정', 'NNG'),
#  ('운영', 'NNG'),
#  ('의', 'JKG'),
#  ('동반자', 'NNG'),
#  ('입니다', 'VCP+EF'),
#  ('.', 'SF'),
#  ('대화', 'NNG'),
#  ('를', 'JKO'),
#  ('정례', 'NNG'),
#  ('화', 'XSN'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('수시로', 'MAG'),
#  ('만나', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('전국', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('고르', 'VV'),
#  ('게', 'EC'),
#  ('인사', 'NNG'),
#  ('를', 'JKO'),
#  ('등용', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('능력', 'NNG'),
#  ('과', 'JC'),
#  ('적재적소', 'NNG'),
#  ('를', 'JKO'),
#  ('인사', 'NNG'),
#  ('의', 'JKG'),
#  ('대원칙', 'NNG'),
#  ('으로', 'JKB'),
#  ('삼', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('에', 'JKB'),
#  ('대한', 'VV+ETM'),
#  ('지지', 'NNG'),
#  ('여부', 'NNG'),
#  ('와', 'JC'),
#  ('상관', 'NNG'),
#  ('없이', 'MAG'),
#  ('유능', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('인재', 'NNG'),
#  ('를', 'JKO'),
#  ('삼', 'VV'),
#  ('고', 'EC'),
#  ('초려', 'NNG'),
#  ('해서', 'XSV+EC'),
#  ('일', 'NNG'),
#  ('을', 'JKO'),
#  ('맡기', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('나라', 'NNG'),
#  ('안팎', 'NNG'),
#  ('으로', 'JKB'),
#  ('경제', 'NNG'),
#  ('가', 'JKS'),
#  ('어렵', 'VA'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('민생', 'NNG'),
#  ('도', 'JX'),
#  ('어렵', 'VA'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('선거', 'NNG'),
#  ('과정', 'NNG'),
#  ('에서', 'JKB'),
#  ('약속', 'NNG'),
#  ('했', 'XSV+EP'),
#  ('듯이', 'EC'),
#  ('무엇', 'NP'),
#  ('보다', 'JKB'),
#  ('먼저', 'MAG'),
#  ('일자리', 'NNG'),
#  ('를', 'JKO'),
#  ('챙기', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('동시', 'NNG'),
#  ('에', 'JKB'),
#  ('재벌', 'NNG'),
#  ('개혁', 'NNG'),
#  ('에', 'JKB'),
#  ('도', 'JX'),
#  ('앞장서', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('문재인', 'NNP'),
#  ('정부', 'NNG'),
#  ('하', 'NNG'),
#  ('에서', 'JKB'),
#  ('는', 'JX'),
#  ('정경', 'NNG'),
#  ('유착', 'NNG'),
#  ('이', 'VCP'),
#  ('라는', 'ETM'),
#  ('낱말', 'NNG'),
#  ('이', 'JKS'),
#  ('완전히', 'MAG'),
#  ('사라질', 'VV+ETM'),
#  ('것', 'NNB'),
#  ('입니다', 'VCP+EF'),
#  ('.', 'SF'),
#  ('지역', 'NNG'),
#  ...]

# %%
# "형태소종합" 변수의 저장 내용 확인
형태소종합
# Out:
#         0       1 type  count
# 0      존경     NNG  문재인      1
# 1       하     XSV  문재인      1
# 2       고      EC  문재인      1
# 3      사랑     NNG  문재인      1
# 4       하     XSV  문재인      1
# ...   ...     ...  ...    ...
# 1502  습니다      EF  문재인      1
# 1503    .      SF  문재인      1
# 1504   감사     NNG  문재인      1
# 1505  합니다  XSV+EF  문재인      1
# 1506    .      SF  문재인      1
#
# [1507 rows x 4 columns]

# %%
# "저장공간" 변수의 저장 내용 확인
저장공간
# Out:
# [        0       1 type  count
#  0      존경     NNG  노무현      1
#  1       하     XSV  노무현      1
#  2       는     ETM  노무현      1
#  3      국민     NNG  노무현      1
#  4     여러분      NP  노무현      1
#  ...   ...     ...  ...    ...
#  2543  합니다  XSV+EF  노무현      1
#  2544    .      SF  노무현      1
#  2545   감사     NNG  노무현      1
#  2546  합니다  XSV+EF  노무현      1
#  2547    .      SF  노무현      1
#
#  [2548 rows x 4 columns],         0       1 type  count
#  0      존경     NNG  이명박      1
#  1       하     XSV  이명박      1
#  2       는     ETM  이명박      1
#  3      국민     NNG  이명박      1
#  4     여러분      NP  이명박      1
#  ...   ...     ...  ...    ...
#  4188  입니다  VCP+EF  이명박      1
#  4189    .      SF  이명박      1
#  4190   감사     NNG  이명박      1
#  4191  합니다  XSV+EF  이명박      1
#  4192    .      SF  이명박      1
#
#  [4193 rows x 4 columns],         0       1 type  count
#  0      희망     NNG  박근혜      1
#  1       의     JKG  박근혜      1
#  2       새      MM  박근혜      1
#  3      시대     NNG  박근혜      1
#  4       를     JKO  박근혜      1
#  ...   ...     ...  ...    ...
#  2589  갑시다   VX+EF  박근혜      1
#  2590    .      SF  박근혜      1
#  2591   감사     NNG  박근혜      1
#  2592  합니다  XSV+EF  박근혜      1
#  2593    .      SF  박근혜      1
#
#  [2594 rows x 4 columns],         0       1 type  count
#  0      존경     NNG  문재인      1
#  1       하     XSV  문재인      1
#  2       고      EC  문재인      1
#  3      사랑     NNG  문재인      1
#  4       하     XSV  문재인      1
#  ...   ...     ...  ...    ...
#  1502  습니다      EF  문재인      1
#  1503    .      SF  문재인      1
#  1504   감사     NNG  문재인      1
#  1505  합니다  XSV+EF  문재인      1
#  1506    .      SF  문재인      1
#
#  [1507 rows x 4 columns]]

# %%
# "저장공간" 변수의 내용을 데이터프레임 형식으로 변환해서 "분석통합" 변수에 저장한다.
분석통합 = pd.concat(저장공간)

# %%
# "분석통합" 변수의 저장 내용 확인
분석통합
# Out:
#         0       1 type  count
# 0      존경     NNG  노무현      1
# 1       하     XSV  노무현      1
# 2       는     ETM  노무현      1
# 3      국민     NNG  노무현      1
# 4     여러분      NP  노무현      1
# ...   ...     ...  ...    ...
# 1502  습니다      EF  문재인      1
# 1503    .      SF  문재인      1
# 1504   감사     NNG  문재인      1
# 1505  합니다  XSV+EF  문재인      1
# 1506    .      SF  문재인      1
#
# [10842 rows x 4 columns]

# %%
# "분석통합" 변수의 컬럼(열) 이름 변경
분석통합.columns = ["형태소", "품사", "분류", "카운트"]

# %%
# "분석통합" 변수의 저장 내용 확인
분석통합
# Out:
#       형태소      품사   분류  카운트
# 0      존경     NNG  노무현    1
# 1       하     XSV  노무현    1
# 2       는     ETM  노무현    1
# 3      국민     NNG  노무현    1
# 4     여러분      NP  노무현    1
# ...   ...     ...  ...  ...
# 1502  습니다      EF  문재인    1
# 1503    .      SF  문재인    1
# 1504   감사     NNG  문재인    1
# 1505  합니다  XSV+EF  문재인    1
# 1506    .      SF  문재인    1
#
# [10842 rows x 4 columns]

# %%
# "분석통합" 변수의 내용을 형태소, 품사, 분류가 같은 것을 합치고, 카운트의 총합을 구해서 "그룹통합" 변수에 저장한다.
그룹통합 = 분석통합.groupby(['형태소', '품사', "분류"])['카운트'].sum()

# %%
# "그룹통합" 변수의 저장 내용 확인
그룹통합
# Out:
# 형태소  품사      분류
# !    SF      박근혜     7
#              이명박     8
#      SY      박근혜     2
#              이명박     1
# '    SY      노무현    10
#                     ..
# 힘    NNG     이명박     5
# 힘들   VA      문재인     1
# 힘쓰   VV      이명박     2
# 힘쓸   VV+ETM  이명박     1
# 힘차   VA      이명박     1
# Name: 카운트, Length: 3151, dtype: int64

# %%
# "그룹통합" 변수의 내용을 데이터프레임 형식으로 변환해서 "그룹통합" 변수에 저장한다.
그룹통합 = pd.DataFrame(그룹통합)

# %%
# "그룹통합" 변수의 저장 내용 확인
그룹통합
# Out:
#                 카운트
# 형태소 품사     분류
# !   SF     박근혜    7
#            이명박    8
#     SY     박근혜    2
#            이명박    1
# '   SY     노무현   10
# ...             ...
# 힘   NNG    이명박    5
# 힘들  VA     문재인    1
# 힘쓰  VV     이명박    2
# 힘쓸  VV+ETM 이명박    1
# 힘차  VA     이명박    1
#
# [3151 rows x 1 columns]

# %%
# "그룹통합" 변수의 내용을 "형태소분석결과.csv" 파일로 저장한다.
# header는 컬럼(열) 정보의 포함 여부이다.
# encoding은 문자코드를 선택하는 것이다. python에서는 기본적으로 utf-8(유니코드)를 사용한다.

그룹통합.to_csv('형태소분석결과.csv', header='true', encoding='utf-8')
